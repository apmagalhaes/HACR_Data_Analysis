# %%
# %matplotlib inline
import pandas
import numpy
import seaborn
import scipy
import matplotlib.pyplot as plt
seaborn.set_context(font_scale=1.5)

# %%
data=pandas.read_excel('/Users/arjun/Google Drive/HDCTF/Data/170914_ABS44_PIN1_phenotyping/Number_coinitiations.xlsx')

fig = seaborn.FacetGrid(data=data,size=5)
fig = fig.map(seaborn.boxplot,'Nem#','Number_coinitations',palette='Greys')
fig = fig.map(seaborn.swarmplot,'Nem#','Number_coinitations','Nem#',palette='YlOrRd')

# looking at anova

anova = scipy.stats.f_oneway(Stem1[Stem1['Nem#']=='ABS44_PIN1_4161']['Number_coinitations'],Stem1[Stem1['Nem#']=='ABS44_3824']['Number_coinitations'])
print('Anova 4161 vs 3824 (Number of coinitiations Stem1): '+str(anova))
# Out:
# Anova 4161 vs 3824 (Number of coinitiations Stem1): F_onewayResult(statistic=10.62618595825427, pvalue=0.002646212440671163)
